# %% [markdown]
# <a href="https://colab.research.google.com/github/pawandamo-cyber/MCA-Assessment-and-practice-/blob/nlp-assessment/SpaCy_Lemmatization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install SpaCy
# !pip install -q spacy

# Import SpaCy
import spacy

# Download the English language model
# !python -m spacy download en_core_web_sm

# Load the English model
nlp = spacy.load("en_core_web_sm")

# Given sentence
sentence = "The cats are running around the house."

# Process the sentence
doc = nlp(sentence)

# Display original words and their lemmas
print("Original Sentence:")
print(sentence)

print("\nLemmatization Result:")
for token in doc:
    print(f"{token.text:12} -> {token.lemma_}")

# Specifically demonstrate 'running' -> 'run'
print("\nSpecific Example:")
for token in doc:
    if token.text.lower() == "running":
        print(f"'{token.text}' is lemmatized to '{token.lemma_}'")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 93.5 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Original Sentence:
# The cats are running around the house.
#
# Lemmatization Result:
# The          -> the
# cats         -> cat
# are          -> be
# running      -> run
# around       -> around
# the          -> the
# house        -> house
# .            -> .
#
# Specific Example:
# 'running' is lemmatized to 'run'
